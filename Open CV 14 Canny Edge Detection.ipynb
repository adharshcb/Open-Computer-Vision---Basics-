# %% [markdown]
# # Canny Edge Detector

# %% [markdown]
# The canny edge detector is an edge detection operator that uses a multi stage algorithm to detect a wide range of edges in images.

# %% [raw]
# steps:
#     1. Noise reduction - smooth image
#     2. Gradient calculation - to find the intensity gradient
#     3. Non-maximum suppression - to get rid of bad response to edge detection.
#     4. Double threshold - to determine the potential edges.
#     5. Edge Tracking by Hysteresis - to finalize the detection of the edges by suppressing all that are weak or not connected to strong edges.

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

# %%
def nothing(x):
    pass

img = cv2.imread('messi5.jpg',0)

cv2.namedWindow('image')
cv2.createTrackbar('A','image',0,255,nothing)
cv2.createTrackbar('B','image',0,255,nothing)

while(1):
    tmin = cv2.getTrackbarPos('A','image')
    tmax = cv2.getTrackbarPos('B','image')
    canny = cv2.Canny(img,tmin,tmax)
    cv2.imshow('image',canny)
    
    if cv2.waitKey(1) == 27:
        break
cv2.destroyAllWindows()
    
#                (source,first-threshold-value,second-threshold-value,)

# %%
title = ['image','canny']
images = [img,canny]
for i in range(len(images)):
    plt.subplot(2,1,i+1)
    plt.imshow(images[i],'gray')
    plt.title(title[i])
    plt.xticks([])
    plt.yticks([])

plt.show()
